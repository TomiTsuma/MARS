# %%
import pandas as pd
import numpy as np
import json
import pickle

# %%
with open(r"C:\Users\tsuma.thomas\.torch_pharma\QM9\QM9_noH_smiles.pickle", "rb") as f:
    print(f)
    smiles_noH = pickle.load(f)
# Out:
# <_io.BufferedReader name='C:\\Users\\tsuma.thomas\\.torch_pharma\\QM9\\QM9_noH_smiles.pickle'>

# %%
len(smiles_noH)
# Out:
# 97864

# %%
with open(r"C:\Users\tsuma.thomas\.torch_pharma\data\nextmol\qm9_lm\raw\uncharacterized.txt", "rb") as f:
    print(len(f.readlines()))
# Out:
# 3064
